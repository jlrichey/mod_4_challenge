# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_path = "Resources/whale_returns.csv"
whale_df = pd.read_csv(whale_path, index_col="Date", parse_dates=True, infer_datetime_format=True).sort_index()
whale_df.head()
# Out:
# /var/folders/h4/gc4497k550l91t9cq44cscm00000gn/T/ipykernel_11671/1211978579.py:3: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   whale_df = pd.read_csv(whale_path, index_col="Date", parse_dates=True, infer_datetime_format=True).sort_index()
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# ...

# %%
# Count nulls
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_df = whale_df.dropna()
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_path = "Resources/algo_returns.csv"
algo_df = pd.read_csv(algo_path, index_col="Date", parse_dates=True, infer_datetime_format=True).sort_index()
# Out:
# /var/folders/h4/gc4497k550l91t9cq44cscm00000gn/T/ipykernel_11671/578881149.py:3: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   algo_df = pd.read_csv(algo_path, index_col="Date", parse_dates=True, infer_datetime_format=True).sort_index()

# %%
# Count nulls
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_df = algo_df.dropna()
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500_path = "Resources/sp500_history.csv"
sp500_df = pd.read_csv(sp500_path, index_col= "Date", parse_dates = True, infer_datetime_format=True).sort_index()
# Out:
# /var/folders/h4/gc4497k550l91t9cq44cscm00000gn/T/ipykernel_11671/995370629.py:3: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   sp500_df = pd.read_csv(sp500_path, index_col= "Date", parse_dates = True, infer_datetime_format=True).sort_index()
# /var/folders/h4/gc4497k550l91t9cq44cscm00000gn/T/ipykernel_11671/995370629.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   sp500_df = pd.read_csv(sp500_path, index_col= "Date", parse_dates = True, infer_datetime_format=True).sort_index()

# %%
# Check Data Types
sp500_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Clean data by removing $ from Close field
sp500_df["Close"] = sp500_df["Close"].str.replace("$", "")

# %%
# Fix Data Types
sp500_df["Close"] = sp500_df["Close"].astype("float")
sp500_df.dtypes
# Out:
# Close    float64
# dtype: object

# %%
# Calculate Daily Returns
sp500_daily_returns = sp500_df.pct_change()

# %%
# Drop nulls
sp500_daily_returns.dropna(inplace=True)
sp500_daily_returns.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
# Rename `Close` Column to be specific to this portfolio.
sp500_daily_returns.rename(columns={'Close': 'S&P 500'}, inplace=True)

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
combined_df = pd.concat([whale_df, algo_df, sp500_daily_returns], axis="columns", join="inner")

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
combined_df.plot(figsize=(10, 5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns = ((1 + combined_df).cumprod()-1)
# Plot cumulative returns
cumulative_returns.plot(figsize=(10, 5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
combined_df.plot.box(figsize=(15, 5), rot=45)
# Out:
# <Axes: >

# %% [markdown]
# ### Calculate Standard Deviations

# %%
combined_df.std()
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# Algo 2                         0.008342
# S&P 500                        0.008554
# dtype: float64

# %%
# Calculate the daily standard deviations of all portfolios
whale_std = whale_df.std()
algo_std = algo_df.std()

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate the daily standard deviation of S&P 500
sp500_std = sp500_daily_returns.std()

# Determine which portfolios are riskier than the S&P 500
combined_std = pd.concat([whale_std, algo_std, sp500_std])
combined_std.sort_values(ascending=False, inplace=True)
combined_std
# Out:
# BERKSHIRE HATHAWAY INC         0.012831
# TIGER GLOBAL MANAGEMENT LLC    0.010824
# Algo 2                         0.008466
# S&P 500                        0.008111
# Algo 1                         0.007988
# SOROS FUND MANAGEMENT LLC      0.007842
# PAULSON & CO.INC.              0.006977
# dtype: float64

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_std = combined_std * np.sqrt(252)
annualized_std
# Out:
# BERKSHIRE HATHAWAY INC         0.203682
# TIGER GLOBAL MANAGEMENT LLC    0.171830
# Algo 2                         0.134401
# S&P 500                        0.128762
# Algo 1                         0.126801
# SOROS FUND MANAGEMENT LLC      0.124487
# PAULSON & CO.INC.              0.110754
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
cumulative_rolling_std21 = combined_df.rolling(window=21).std()

# Plot the rolling standard deviation
cumulative_rolling_std21.plot(figsize=(10,5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
price_correlation = combined_df.corr()

# Display de correlation matrix
price_correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# S&P 500                                       0.837864            0.669732
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# Algo 1                                          0.164387
# ...

# %% [markdown]
# ### Calculate and Rolling Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
covariance_soros = combined_df["SOROS FUND MANAGEMENT LLC"].rolling(60).cov(combined_df["S&P 500"])

# Calculate variance of S&P 500
variance_sp500 = combined_df["S&P 500"].rolling(60).var()

# Computing beta
soros_beta = covariance_soros / variance_sp500

# Plot beta trend
soros_beta.plot(figsize=(10, 5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window
combined_df_ewm = combined_df.ewm(halflife=21).std()
combined_df_ewm.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratios = (combined_df.mean() * 252) / (annualized_std * np.sqrt(252))
sharpe_ratios
# Out:
# Algo 1                         0.082851
# Algo 2                         0.031120
# BERKSHIRE HATHAWAY INC         0.039439
# PAULSON & CO.INC.             -0.030664
# S&P 500                        0.043065
# SOROS FUND MANAGEMENT LLC      0.022605
# TIGER GLOBAL MANAGEMENT LLC   -0.007675
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot.bar(title="Sharpe Ratios")
# Out:
# <Axes: title={'center': 'Sharpe Ratios'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Write your answer here!
#
# Algorithmic strategy one, with a Sharpe ratio of over .08, outperforms the the market (S&P 500) and the whale portfolios.
#
# Algorithmic strategy two, with a Sharpe ratio of approximately .03, does not outperform the market (S&P 500). It does outperform the whale portfolios, with the exception of Berkshire Hathaway.

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
msft_path = "Resources/msft_historical.csv"
msft_df = pd.read_csv(msft_path, index_col= "Date", parse_dates = True).sort_index()
msft_df.head()
# Out:
#             Close
# Date
# 2015-03-02  43.88
# 2015-03-03  43.28
# 2015-03-04  43.06
# 2015-03-05  43.11
# 2015-03-06  42.36

# %%
# Reading data from 2nd stock
now_path = "Resources/now_historical.csv"
now_df = pd.read_csv(now_path, index_col= "Date", parse_dates = True).sort_index()
now_df.head()
# Out:
#             Close
# Date
# 2015-03-02  76.44
# 2015-03-03  75.45
# 2015-03-04  73.60
# 2015-03-05  74.70
# 2015-03-06  74.06

# %%
# Reading data from 3rd stock
eqt_path = "Resources/eqt_historical.csv"
eqt_df = pd.read_csv(eqt_path, index_col= "Date", parse_dates = True).sort_index()
eqt_df.head()
# Out:
#             Close
# Date
# 2015-03-02  43.91
# 2015-03-03  44.76
# 2015-03-04  44.01
# 2015-03-05  43.85
# 2015-03-06  43.29

# %%
# Combine all stocks in a single DataFrame
personal_df = pd.concat([msft_df, now_df, eqt_df], axis="columns", join="inner").sort_index()
personal_df.columns = ["MSFT", "NOW", "EQT"]
personal_df.head()
# Out:
#              MSFT    NOW    EQT
# Date
# 2015-03-02  43.88  76.44  43.91
# 2015-03-03  43.28  75.45  44.76
# 2015-03-04  43.06  73.60  44.01
# 2015-03-05  43.11  74.70  43.85
# 2015-03-06  42.36  74.06  43.29

# %%
## Not necessary per professor, due to my import approach. Date is already index.

# Reset Date index
#personal_df2 = personal_df.reset_index()

# %%
## Not necessary per professor, due to my import approach. Already inherent in import.

# Reorganize portfolio data by having a column per symbol
#personal_df2.head()

# %%
# Calculate daily returns
personal_df = personal_df.pct_change()

# Drop NAs
personal_df = personal_df.dropna()

# Display sample data
personal_df.describe()
# Out:
#               MSFT          NOW          EQT
# count  1049.000000  1049.000000  1049.000000
# mean      0.001129     0.001458    -0.000486
# std       0.014839     0.022415     0.022780
# min      -0.071710    -0.156561    -0.126249
# 25%      -0.005420    -0.008787    -0.012647
# 50%       0.000835     0.001801    -0.000567
# 75%       0.007832     0.012455     0.012614
# max       0.104522     0.140685     0.101194

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
personal_returns = personal_df.dot(weights)

# Display sample data
personal_returns
# Out:
# Date
# 2015-03-03   -0.002422
# 2015-03-04   -0.015453
# 2015-03-05    0.004157
# 2015-03-06   -0.012912
# 2015-03-09   -0.005806
#                 ...
# 2019-04-25    0.026269
# 2019-04-26    0.023804
# 2019-04-29    0.006716
# 2019-04-30   -0.007897
# 2019-05-01   -0.014336
# Length: 1049, dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
combined_df['PERSONAL'] = personal_returns

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
combined_df.dropna()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
# 2019-04-23                   0.007167            0.003485
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# ...

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
annualized_combined_std = combined_df.std() * np.sqrt(252)
annualized_combined_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.125335
# PAULSON & CO.INC.              0.111488
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# BERKSHIRE HATHAWAY INC         0.205077
# Algo 1                         0.120967
# Algo 2                         0.132430
# S&P 500                        0.135786
# PERSONAL                       0.228792
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
cumulative_rolling_std21 = combined_df.rolling(window=21).std()

# Plot rolling standard deviation
cumulative_rolling_std21.plot(figsize=(10,5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
combined_price_correlation = combined_df.corr()
sns.heatmap(combined_price_correlation, vmin=-1, vmax=1)
# Out:
# <Axes: >

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta

# Calculating covariance and variance for beta calculation
covariance_personal = combined_df["PERSONAL"].rolling(60).cov(combined_df["S&P 500"])
variance2_sp500 = combined_df["S&P 500"].rolling(60).var()

# Calculating beta for personal portfolio
personal_beta = covariance_personal / variance2_sp500

# Plot the beta for personal portfolio
personal_beta.plot(figsize=(10, 5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
combined_sharpe_ratios = (combined_df.mean() * 252) / (annualized_combined_std * np.sqrt(252))
combined_sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.022452
# PAULSON & CO.INC.             -0.030462
# TIGER GLOBAL MANAGEMENT LLC   -0.007626
# BERKSHIRE HATHAWAY INC         0.039170
# Algo 1                         0.086847
# Algo 2                         0.031583
# S&P 500                        0.040837
# PERSONAL                       0.047006
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
combined_sharpe_ratios.plot.bar(title="Sharpe Ratios")
# Out:
# <Axes: title={'center': 'Sharpe Ratios'}>

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!
#
# With a Sharpe ratio of 0.047, my portfolio outperforms the market (S&P 500) and all other portfolios except the Algo 1 portfolio.
